# %% [markdown]
# # Made to play around with the python_learning_journey.py file.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# #### Some math basics

# %%
2 + 2
# this will print 4
# Out:
# 10

# %%
import math
a = math.sqrt(25)
#print(type(a))

b = 3.25 + 4.75
print(b)
print(type(b))
# Out:
# <class 'float'>
# 8.0
# <class 'float'>

# %%
# -----------------------------
# SECTION 3: OPERATORS
# -----------------------------
# Arithmetic operators: + - * / // % **
# Comparison operators: == != > < >= <=
# Logical operators: and or not
print("\n=== Section 3: Operators ===")
a = 10
b = 3
print("a + b =", a + b)
print("a - b =", a - b)
print("a * b =", a * b)
print("a / b =", a / b)    # True division (float result)
print("a // b =", a // b)  # Floor division (integer-like quotient)
print("a % b =", a % b)    # Remainder
print("a ** b =", a ** b)  # Exponentiation (10^3)

print("a > b:", a > b)
print("a == b:", a == b)
print("(a > 5) and (b < 5):", (a > 5) and (b < 5))
print("(a > 5) or (b < 5):", (a > 5) or (b < 5))
print("not (a > 5):", not (a < 5))
# Out:
# === Section 3: Operators ===
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a // b = 3
# a % b = 1
# a ** b = 1000
# a > b: True
# a == b: False
# (a > 5) and (b < 5): True
# (a > 5) or (b < 5): True
# not (a > 5): True
